# %% [markdown]
# Data Analysis relationshoip between of NOx emission and concentration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# Import 2019 Emissions Summary Datasets

# %%
#Please change the path to your 2019 emissions summary file
#I convert the file to csv only because excel works super slow on my computer
emission_summary = pd.read_csv('datasets/LAEI-2019-Emissions-Summary-including-Forecast.csv')
emission_summary.head(5)
# Out:
#    Year  Grid ID 2019  LAEI 1km2 ID  Easting  Northing  Borough     Zone  \
# 0  2030             1          5910   510500    203500  Non GLA  Non GLA
# 1  2030             2          5911   511500    203500  Non GLA  Non GLA
# 2  2030             3          5912   512500    203500  Non GLA  Non GLA
# 3  2030             4          5915   515500    203500  Non GLA  Non GLA
# 4  2030             5          5916   516500    203500  Non GLA  Non GLA
#
#   Main Source Category   Sector        Source  ...  n2o  nh3  nmvoc  nox  pb  \
# 0             Domestic  Biomass  Wood Burning  ...  NaN  NaN    NaN  NaN NaN
# 1             Domestic  Biomass  Wood Burning  ...  NaN  NaN    NaN  NaN NaN
# 2             Domestic  Biomass  Wood Burning  ...  NaN  NaN    NaN  NaN NaN
# 3             Domestic  Biomass  Wood Burning  ...  NaN  NaN    NaN  NaN NaN
# 4             Domestic  Biomass  Wood Burning  ...  NaN  NaN    NaN  NaN NaN
#
#    pcb      pm10     pm2.5  so2  Emissions Unit
# 0  NaN  0.019183  0.019183  NaN    tonnes/annum
# 1  NaN  0.015719  0.015719  NaN    tonnes/annum
# 2  NaN  0.019878  0.019878  NaN    tonnes/annum
# 3  NaN  0.020946  0.020946  NaN    tonnes/annum
# 4  NaN  0.020105  0.020105  NaN    tonnes/annum
#
# [5 rows x 30 columns]

# %%
emissions2019 = emission_summary[(emission_summary['Year'] == 2019)]
unqiue_data = emissions2019['Year'].unique()
unqiue_data
# Out:
# array([2019])

# %%
rename_emission2019 = emissions2019.rename(columns={'Easting': 'x', 'Northing': 'y'})
emissions2019.shape
# Out:
# (143976, 30)

# %% [raw]
# import NOx oncentration dataset

# %%
conc_nox = pd.read_csv('datasets/laei_LAEI2019v3_CorNOx15_NOx.csv')
conc_no2 = pd.read_csv('datasets/laei_LAEI2019v3_CorNOx15_NO2.csv')
conc_pm10 = pd.read_csv('datasets/laei_LAEI2019v3_CorNOx15_PM10m.csv')
conc_pm25 = pd.read_csv('datasets/laei_LAEI2019v3_CorNOx15_PM25.csv')

# %%
print(
    f"Shape of conc_nox: {conc_nox.shape}\n"
    f"Shape of conc_no2: {conc_no2.shape}\n"
    f"Shape of conc_pm10: {conc_pm10.shape}\n"
    f"Shape of conc_pm25: {conc_pm25.shape}"
)
# Out:
# Shape of conc_nox: (5851964, 3)
# Shape of conc_no2: (5851964, 3)
# Shape of conc_pm10: (5851964, 3)
# Shape of conc_pm25: (5851964, 3)

# %%
# Rename the 'conc' column in each dataset
conc_nox.rename(columns={'conc': 'conc_NOx'}, inplace=True)
conc_no2.rename(columns={'conc': 'conc_NO2'}, inplace=True)
conc_pm10.rename(columns={'conc': 'conc_PM10'}, inplace=True)
conc_pm25.rename(columns={'conc': 'conc_PM25'}, inplace=True)

# Print the first few rows of each dataset to confirm the change
print(conc_nox.head())
print(conc_no2.head())
print(conc_pm10.head())
print(conc_pm25.head())
# Out:
#         x       y  conc_NOx
# 0  519100  203440  37.54391
# 1  519120  203440  40.60276
# 2  519140  203440  47.19806
# 3  519160  203440  43.32369
# 4  519180  203440  39.57808
#         x       y  conc_NO2
# 0  519100  203440  23.50290
# 1  519120  203440  24.58045
# 2  519140  203440  26.86432
# 3  519160  203440  25.52398
# 4  519180  203440  24.20996
#         x       y  conc_PM10
# 0  519100  203440   15.09522
# 1  519120  203440   15.51029
# 2  519140  203440   16.40831
# 3  519160  203440   15.87096
# 4  519180  203440   15.34885
#         x       y  conc_PM25
# 0  519100  203440   9.567125
# 1  519120  203440   9.687501
# 2  519140  203440   9.953107
# 3  519160  203440   9.791943
# 4  519180  203440   9.635820

# %% [raw]
# Merge four concetration dataset together based on x, y

# %%
merged_conc_data = conc_nox.merge(conc_no2, on=['x', 'y']) \
                      .merge(conc_pm10, on=['x', 'y']) \
                      .merge(conc_pm25, on=['x', 'y'])
print(merged_conc_data.head(5))
print(merged_conc_data.shape)
# Out:
#         x       y  conc_NOx  conc_NO2  conc_PM10  conc_PM25
# 0  519100  203440  37.54391  23.50290   15.09522   9.567125
# 1  519120  203440  40.60276  24.58045   15.51029   9.687501
# 2  519140  203440  47.19806  26.86432   16.40831   9.953107
# 3  519160  203440  43.32369  25.52398   15.87096   9.791943
# 4  519180  203440  39.57808  24.20996   15.34885   9.635820
# (5851964, 6)

# %% [markdown]
# The emissions2019 has 143976 rows while the concentrations has 5851964 rows. This is because the concentration data is recorded at a finer spatial resolution (20m grid resolution vs. 1km grid square resolution).

# %%
merged_data = pd.merge(rename_emission2019, merged_conc_data, on =['x','y'], how= 'inner')
print(merged_data.head(5))
print(merged_data.shape)
# Out:
#    Year  Grid ID 2019  LAEI 1km2 ID       x       y  Borough     Zone  \
# 0  2019            10          6081  509500  202500  Non GLA  Non GLA
# 1  2019            11          6082  510500  202500  Non GLA  Non GLA
# 2  2019            12          6083  511500  202500  Non GLA  Non GLA
# 3  2019            13          6084  512500  202500  Non GLA  Non GLA
# 4  2019            14          6085  513500  202500  Non GLA  Non GLA
#
#   Main Source Category   Sector        Source  ...  pb  pcb      pm10  \
# 0             Domestic  Biomass  Wood Burning  ... NaN  NaN  0.113548
# 1             Domestic  Biomass  Wood Burning  ... NaN  NaN  0.048413
# 2             Domestic  Biomass  Wood Burning  ... NaN  NaN  0.022535
# 3             Domestic  Biomass  Wood Burning  ... NaN  NaN  0.032564
# 4             Domestic  Biomass  Wood Burning  ... NaN  NaN  0.060357
#
#       pm2.5  so2  Emissions Unit  conc_NOx  conc_NO2  conc_PM10  conc_PM25
# 0  0.113548  NaN    tonnes/annum  26.09821  19.27811   13.16673   9.132265
# 1  0.048413  NaN    tonnes/annum  25.48599  19.25023   12.98150   9.039471
# 2  0.022535  NaN    tonnes/annum  26.44346  19.83410   13.00581   9.066235
# 3  0.032564  NaN    tonnes/annum  27.99726  20.37540   13.34289   9.210483
# 4  0.060357  NaN    tonnes/annum  30.60220  21.22061   13.81937   9.251517
#
# [5 rows x 34 columns]
# (137910, 34)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137910 entries, 0 to 137909
# Data columns (total 34 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Year                  137910 non-null  int64
#  1   Grid ID 2019          137910 non-null  int64
#  2   LAEI 1km2 ID          137910 non-null  int64
#  3   x                     137910 non-null  int64
#  4   y                     137910 non-null  int64
#  5   Borough               137910 non-null  object
#  6   Zone                  137910 non-null  object
#  7   Main Source Category  137910 non-null  object
#  8   Sector                137910 non-null  object
#  9   Source                137910 non-null  object
#  10  bap                   29835 non-null   float64
#  11  cd                    16575 non-null   float64
#  12  c4h6                  33150 non-null   float64
#  13  c6h6                  43095 non-null   float64
#  14  ch4                   49725 non-null   float64
#  15  co                    49725 non-null   float64
#  16  co2                   108075 non-null  float64
#  17  hc                    6630 non-null    float64
#  18  hcl                   9945 non-null    float64
#  19  hg                    19890 non-null   float64
#  20  n2o                   33150 non-null   float64
#  21  nh3                   29835 non-null   float64
#  22  nmvoc                 53040 non-null   float64
#  23  nox                   118020 non-null  float64
#  24  pb                    19890 non-null   float64
#  25  pcb                   23205 non-null   float64
#  26  pm10                  134595 non-null  float64
#  27  pm2.5                 134595 non-null  float64
#  28  so2                   33150 non-null   float64
#  29  Emissions Unit        137910 non-null  object
#  30  conc_NOx              137910 non-null  float64
#  31  conc_NO2              137910 non-null  float64
#  32  conc_PM10             137910 non-null  float64
#  33  conc_PM25             137910 non-null  float64
# dtypes: float64(23), int64(5), object(6)
# memory usage: 35.8+ MB

# %%
#Clean the columns
col_to_drop = ['Grid ID 2019','LAEI 1km2 ID','bap','cd','c4h6','c6h6',
               'ch4','co','co2','hc','hcl','hg','n2o','nh3','nmvoc',
               'pb','pcb','so2','Emissions Unit']
clean_data = merged_data.drop(columns=col_to_drop)
clean_data.head(5)
# Out:
#    Year       x       y  Borough     Zone Main Source Category   Sector  \
# 0  2019  509500  202500  Non GLA  Non GLA             Domestic  Biomass
# 1  2019  510500  202500  Non GLA  Non GLA             Domestic  Biomass
# 2  2019  511500  202500  Non GLA  Non GLA             Domestic  Biomass
# 3  2019  512500  202500  Non GLA  Non GLA             Domestic  Biomass
# 4  2019  513500  202500  Non GLA  Non GLA             Domestic  Biomass
#
#          Source  nox      pm10     pm2.5  conc_NOx  conc_NO2  conc_PM10  \
# 0  Wood Burning  NaN  0.113548  0.113548  26.09821  19.27811   13.16673
# 1  Wood Burning  NaN  0.048413  0.048413  25.48599  19.25023   12.98150
# 2  Wood Burning  NaN  0.022535  0.022535  26.44346  19.83410   13.00581
# 3  Wood Burning  NaN  0.032564  0.032564  27.99726  20.37540   13.34289
# 4  Wood Burning  NaN  0.060357  0.060357  30.60220  21.22061   13.81937
#
#    conc_PM25
# 0   9.132265
# 1   9.039471
# 2   9.066235
# 3   9.210483
# 4   9.251517

# %%
clean_data[['nox','pm10','pm2.5','conc_NOx','conc_NO2','conc_PM10','conc_PM25']].describe()
# Out:
#                  nox           pm10          pm2.5       conc_NOx  \
# count  118020.000000  134595.000000  134595.000000  137910.000000
# mean        0.360092       0.064948       0.028878      37.848242
# std         4.683387       0.704482       0.175601      15.420628
# min         0.000000       0.000000       0.000000      20.233480
# 25%         0.000000       0.000000       0.000000      28.317600
# 50%         0.001789       0.000838       0.000483      34.883620
# 75%         0.098958       0.019089       0.010925      42.658240
# max      1000.194271     114.906839      21.364992     279.093700
#
#             conc_NO2      conc_PM10      conc_PM25
# count  137910.000000  137910.000000  137910.000000
# mean       25.110811      15.414833      10.197908
# std         5.853568       2.591527       0.980566
# min        16.566730      12.215170       8.835211
# 25%        20.873780      13.702890       9.497413
# 50%        24.103170      14.933130      10.066390
# 75%        27.789940      16.303560      10.615150
# max        82.963260      45.239320      20.049840

# %%
# % of missing values
clean_data.isna().mean() * 100
# Out:
# Year                     0.000000
# x                        0.000000
# y                        0.000000
# Borough                  0.000000
# Zone                     0.000000
# Main Source Category     0.000000
# Sector                   0.000000
# Source                   0.000000
# nox                     14.422449
# pm10                     2.403742
# pm2.5                    2.403742
# conc_NOx                 0.000000
# conc_NO2                 0.000000
# conc_PM10                0.000000
# conc_PM25                0.000000
# dtype: float64

# %% [raw]
# Show the plot of NOx emission and concentration level of NOx.
# Both plots share a consistent color interval to enhance interpretability and allow direct comparisons of intensity distributions.

# %%
commom_min = min(merged_data['nox'].min(),merged_data['conc'].min())
common_max = max(merged_data['nox'].max(),merged_data['conc'].max())

color_nor = np.linspace(commom_min, common_max, 10)
# Plot for NOx Emission Level
plt.figure(figsize = (12,6))
scatter_nox = plt.scatter(merged_data['x'], merged_data['y'], c=merged_data['nox'], cmap ='bone', vmin=commom_min, vmax=common_max, alpha= 0.5)
plt.colorbar(scatter_nox, label='Unified Levels')
plt.title('Distribution of NOx Levels')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.grid(True)
plt.show

# Plot for Concentration Level
plt.figure(figsize = (12,6))
scatter_conc = plt.scatter(merged_data['x'], merged_data['y'], c=merged_data['conc'], cmap ='bone', vmin=commom_min, vmax=common_max, alpha= 0.5)
plt.colorbar(scatter_conc, label='Unified Levels')
plt.title('Distribution of Concentration Levels')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.grid(True)
plt.show

# %%
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
scaler = MinMaxScaler()

merged_data[['nox_normalized', 'nox_conc_normalized']] = scaler.fit_transform(merged_data[['nox', 'conc']])
# Plot the scatter plots again using the normalized values
plt.figure(figsize=(12, 6))
sns.scatterplot(x='x', y='y', hue='nox_normalized', data=merged_data, palette='coolwarm')
plt.title('Normalized NOx Emissions Spatial Distribution')
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(x='x', y='y', hue='nox_conc_normalized', data=merged_data, palette='coolwarm')
plt.title('Normalized NOx Concentrations Spatial Distribution')
plt.show()

# %%
# Create a Scatter plot to check for outliners
plt.figure(figsize=(8, 6))
plt.scatter(merged_data['nox'], merged_data['conc'], alpha=0.7)
plt.title('Scatter Plot of NOx vs. Concentration')
plt.xlabel('NOx Emission (t/year)')
plt.ylabel('Concentration (µg/m³)')
plt.grid(True)
plt.show()

# %%
missing_values = merged_data.isnull().sum()
missing_values
